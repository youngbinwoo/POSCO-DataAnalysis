# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import re


pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
matplotlib.rc('font',family='NanumGothic')
df_product=pd.read_csv("./master_product_sheet_000.csv")
# Out:
# /home/piai/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   if __name__ == '__main__':

# %%
df_product.columns
# Out:
# Index(['#', '공급사', '과세/면세', '담기', '매입가', '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가', '품절여부', '후기'], dtype='object')

# %%
df_product.isnull().sum()
# Out:
# #          0
# 공급사        0
# 과세/면세      0
# 담기         0
# 매입가        0
# 상품명(기본)    0
# 상품코드       0
# 재입고알림      0
# 제조사        486
# 카테고리       0
# 판매가        0
# 품절여부       0
# 후기         0
# dtype: int64

# %%
df_product["카테고리"].unique()
# Out:
# array(['018 : 실링용기\n018002 : 실링용기 > 2319(2318)시리즈\n042 : 실링제품\n042001 : 실링제품 > 실링용기\n061 : vol.4 Catalogue\n061012 : vol.4 Catalogue > 카달로그_12',
#        '002 : 주방용품\n002002 : 주방용품 > 주방용품\n046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n046007002 : 주방용품/소모품 > 주방용품 > 쟁반',
#        '002 : 주방용품\n002002 : 주방용품 > 주방용품\n046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n046007004 : 주방용품/소모품 > 주방용품 > 식기',
#        '002 : 주방용품\n002002 : 주방용품 > 주방용품\n046 : 주방용품/소모품\n046010 : 주방용품/소모품 > 주방잡화\n046010003 : 주방용품/소모품 > 주방잡화 > 기타',
#        '002 : 주방용품\n002002 : 주방용품 > 주방용품\n046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n046007009 : 주방용품/소모품 > 주방용품 > 기타',
#        '050 : 식자재\n050001 : 식자재 > 한식 식자재\n050001012 : 식자재 > 한식 식자재 > 김\n026 : NEW\n026010 : NEW > 식자재\n026010001 : NEW > 식자재 > 한식 식자재\n026010001012 : NEW > 식자재 > 한식 식자재 > 김',
#        '046 : 주방용품/소모품\n046009 : 주방용품/소모품 > 일회용품\n046009002 : 주방용품/소모품 > 일회용품 > 냅킨/물티슈',
# ...

# %%
def change(x):
    i=re.findall(r"\d{3} : \w+",str(x))
    if(i[0].contains("new")):
        return i[1]
    else:
        return i[0]

# %%
df_product["상품명(기본)"].value_counts().head(5)
# Out:
# [201H 몰드 추가 구매]                  2
# 니드코 뉴카멜리아 사각수저함(수저통)             2
# 실링용기 71호 백색 2,200ml 400개 1박스     2
# 210파이 탕용기 소 백색 200개 1set(2박스)    1
# 디벨라 칙피스 400g 24개 (박스 상품)         1
# Name: 상품명(기본), dtype: int64

# %%
idx=df_product[(df_product["상품명(기본)"]=="실링용기 71호 백색 2,200ml 400개 1박스") & (df_product["상품코드"]==2184)].index

# %%
idx
# Out:
# Int64Index([0], dtype='int64')

# %%
df_product["상품명(기본)"].value_counts().head(500)
# Out:
# [201H 몰드 추가 구매]                                                2
# 니드코 뉴카멜리아 사각수저함(수저통)                                           2
# 실링용기 71호 백색 2,200ml 400개 1박스                                   2
# 210파이 탕용기 소 백색 200개 1set(2박스)                                  1
# 디벨라 칙피스 400g 24개 (박스 상품)                                       1
# 신형볼 210 230개 (1BOX)                                            1
# 195파이 미니탕용기 투톤 300개 1set(2박스)                                  1
# 세미 요거레또믹스(파우더) 1kg 1개 (낱개 상품)                                  1
# 모닌 케인슈가 1L 1개 (낱개 상품)                                          1
# 105파이 다용도컵 세트 5호 대 370ml 투명 PS 1,000개 1set(2박스)                1
# 샘표 연두(순) 930ml 12병 (박스 상품)                                     1
# 75파이 다용도컵 세트 3호 대 165ml 백색 PS 3,000개 1set(2박스)                 1
# 175mm 수저 투명 1,500개 맛있숟갈                                        1
# ADMIRAL 닭고기향 시즈닝 680g 1개 (낱개 상품)                               1
# ...

# %%
df_product=df_product.drop(idx)

# %%
df_product["상품명(기본)"].value_counts().head(500)
# Out:
# [201H 몰드 추가 구매]                                                2
# 니드코 뉴카멜리아 사각수저함(수저통)                                           2
# 모닌 블루베리시럽 1L (낱개 상품)                                           1
# 다회용 피크닉세트 8인용(56P)                                             1
# ADMIRAL 닭고기향 시즈닝 680g 1개 (낱개 상품)                               1
# 175mm 수저 투명 1,500개 맛있숟갈                                        1
# 75파이 다용도컵 세트 3호 대 165ml 백색 PS 3,000개 1set(2박스)                 1
# 105파이 다용도컵 세트 5호 대 370ml 투명 PS 1,000개 1set(2박스)                1
# 모닌 케인슈가 1L 1개 (낱개 상품)                                          1
# 세미 요거레또믹스(파우더) 1kg 1개 (낱개 상품)                                  1
# 195파이 미니탕용기 투톤 300개 1set(2박스)                                  1
# 신형볼 210 230개 (1BOX)                                            1
# 디벨라 칙피스 400g 24개 (박스 상품)                                       1
# 210파이 탕용기 소 백색 200개 1set(2박스)                                  1
# ...

# %%
idx1=df_product[(df_product["상품명(기본)"]=="니드코 뉴카멜리아 사각수저함(수저통)") &(df_product["상품코드"]==2178)].index

# %%
idx1
# Out:
# Int64Index([4], dtype='int64')

# %%
df_product=df_product.drop(idx1)

# %%
df_product["상품명(기본)"].value_counts().head(500)
# Out:
# [201H 몰드 추가 구매]                                                2
# 종이빨대 백색 8mm x 209mm 2,000개 1박스                                 1
# 미소크린 핸드타올 90매*40밴드                                             1
# 다회용 피크닉세트 8인용(56P)                                             1
# ADMIRAL 닭고기향 시즈닝 680g 1개 (낱개 상품)                               1
# 175mm 수저 투명 1,500개 맛있숟갈                                        1
# 75파이 다용도컵 세트 3호 대 165ml 백색 PS 3,000개 1set(2박스)                 1
# 105파이 다용도컵 세트 5호 대 370ml 투명 PS 1,000개 1set(2박스)                1
# 모닌 케인슈가 1L 1개 (낱개 상품)                                          1
# 세미 요거레또믹스(파우더) 1kg 1개 (낱개 상품)                                  1
# 195파이 미니탕용기 투톤 300개 1set(2박스)                                  1
# 신형볼 210 230개 (1BOX)                                            1
# 디벨라 칙피스 400g 24개 (박스 상품)                                       1
# 210파이 탕용기 소 백색 200개 1set(2박스)                                  1
# ...
