# %%
import pandas as pd
import seaborn as sns

# %%
df_member = pd.read_csv("master_member_sheet_000.csv")

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rc('font', family = "NanumGothic")

df_member.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff551ff0410>,
# ...
#       dtype=object)

# %%
df_member.boxplot(figsize=(13,10))

# %%
df_member["나이"].unique()

df_member["나이"].hist()

# %%
# 사용가능 적립금

df_member["사용가능 적립금"].unique()
# - 값 발생

df_member["사용가능 적립금"].hist()

# %%
df_member["성별"].unique()

df_member["성별"].hist()

# %%
df_member["주소(동/읍/면)"].unique()
df_member["주소(동/읍/면)"].isnull().sum()

# %%
df_member["최종접속일"].unique()
df_member["최종접속일"].isnull().sum()

# %%
df_member["유입경로"].unique()
df_member["유입경로"].isnull().sum()

plt.figure(figsize=(13,5))
df_member["유입경로"].hist()

# %%
df_member["회원 가입일"].unique()
df_member["회원 가입일"].isnull().sum()

# %%
df_member["사업자구분"].unique()
#df_member["사업자구분"].isnull().sum()

df_member["사업자구분"].hist()

# %%
df_member["회원구분"].unique()
#df_member["회원구분"].isnull().sum()

plt.figure(figsize=(13,5))
df_member["회원구분"].hist()

# %%
df_member.hist(figsize=(30,20),bins=100)

# %%
df_member.boxplot(figsize=(13,10))

# %%
df_member["나이"].hist()

# %%
df_member["나이"].hist(range = (60, 90))

# %%
df_member["사용가능 적립금"].hist()

# %%
df_member["사용가능 적립금"].max()
# Out:
# 125490

# %%
df_member["사용가능 적립금"].hist(range = (80000, 120000))

# %%
df_member["유입경로"].hist()

# %%
df_member["유입경로"].value_counts()
# Out:
# SNS광고      1098
# 블로그광고      1087
# 유튜브광고       944
# 전단지광고       861
# 이메일광고       611
# 잡지광고        505
# 인터넷검색       423
# 지인추천        390
# 기타          269
# 카카오톡광고      182
# 인터넷기사광고     161
# 신문광고         44
# Name: 유입경로, dtype: int64

# %%
df_member["사업자구분"].value_counts()
# Out:
# 개인     4039
# 사업자    2534
# 외국인       2
# Name: 사업자구분, dtype: int64

# %%
df_member["사업자구분"].isnull().sum()
# Out:
# 0

# %%
df_member["회원구분"].value_counts()
# Out:
# 일반           2575
# 사업자          2160
# 전화주문 고객      1668
# 딜러 유치 회원      132
# 특별회원           15
# 딜러             10
# 일반(수신거부)        6
# 관리자             4
# 사업자(수신거부)       4
# VIP             1
# Name: 회원구분, dtype: int64
